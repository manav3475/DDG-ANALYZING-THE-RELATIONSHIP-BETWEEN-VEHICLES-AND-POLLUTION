# %%
import pandas as pd
import numpy as np
from pandas.plotting import scatter_matrix

#Pre-processing
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder

#Plots and graphs
import matplotlib.pyplot as plt  
import seaborn as sns
# %matplotlib inline
# %cd E:\M.Sc(DS & SA)\Sem-2\Data Driven Governance\Final Project Data\Final Datasets\Ref Data Set
# Out:
# E:\M.Sc(DS & SA)\Sem-2\Data Driven Governance\Final Project Data\Final Datasets\Ref Data Set

# %%
df = pd.read_csv("Air_quality_index.csv")
df
# Out:
#                           State  SO2 - 2011  NO2 - 2011  PM - 2011  \
# 0                Andhra Pradesh         7.0        20.0       86.0
# 1                         Assam         NaN         NaN        NaN
# 2                         Bihar         NaN         NaN        NaN
# 3                    Chandigarh         2.0        15.0       81.0
# 4                  Chhattisgarh        16.0        31.0      164.0
# 5          Dadra & Nagar Haveli         NaN         NaN        NaN
# 6                   Daman & Diu         NaN         NaN        NaN
# 7                         Delhi         6.0        50.0      252.0
# 8                           Goa         3.0        14.0       74.0
# 9                       Gujarat        16.0        24.0       92.0
# 10                      Haryana        13.0        20.0      168.0
# 11             Himachal Pradesh         3.0        13.0       89.0
# 12                    Jharkhand        23.0        42.0      186.0
# ...

# %% [markdown]
# # Count Data frame Attribute Null Value

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
plt.figure(figsize=(25, 18))
sns.set_style('whitegrid')

# %%
df.isnull().sum()
# Out:
# State          0
# SO2 - 2011     8
# NO2 - 2011     8
# PM - 2011     10
# SO2 - 2012     9
# NO2 - 2012     9
# PM - 2012     10
# SO2 - 2013     8
# NO2 - 2013     8
# PM - 2013     10
# SO2 - 2014     4
# NO2 - 2014     4
# PM - 2014      8
# VR_2011        0
# VR_2012        0
# VR_2013        0
# VR_2014        0
# dtype: int64

# %%
df2 = df.drop("State",axis=1)
df2
# Out:
#     SO2 - 2011  NO2 - 2011  PM - 2011  SO2 - 2012  NO2 - 2012  PM - 2012  \
# 0          7.0        20.0       86.0         5.0        17.0       73.0
# 1          NaN         NaN        NaN         NaN         NaN        NaN
# 2          NaN         NaN        NaN         NaN         NaN        NaN
# 3          2.0        15.0       81.0         2.0        16.0       92.0
# 4         16.0        31.0      164.0        11.0        22.0      107.0
# 5          NaN         NaN        NaN         NaN         NaN        NaN
# 6          NaN         NaN        NaN         NaN         NaN        NaN
# 7          6.0        50.0      252.0         5.0        55.0      261.0
# 8          3.0        14.0       74.0        14.0        18.0       68.0
# 9         16.0        24.0       92.0        15.0        23.0       89.0
# 10        13.0        20.0      168.0        14.0        23.0      171.0
# 11         3.0        13.0       89.0         3.0        15.0       88.0
# ...

# %% [markdown]
# # Data Frame Impute Using for Missing Data(Data Preprosessing)

# %%
df.dtypes
# Out:
# State          object
# SO2 - 2011    float64
# NO2 - 2011    float64
# PM - 2011     float64
# SO2 - 2012    float64
# NO2 - 2012    float64
# PM - 2012     float64
# SO2 - 2013    float64
# NO2 - 2013    float64
# PM - 2013     float64
# SO2 - 2014    float64
# NO2 - 2014    float64
# PM - 2014     float64
# VR_2011         int64
# VR_2012         int64
# VR_2013         int64
# VR_2014         int64
# dtype: object

# %%
imputer = SimpleImputer(missing_values=np.nan,strategy='mean')
df_trans=imputer.fit_transform(df2)
df_trans
# Out:
# array([[7.00000000e+00, 2.00000000e+01, 8.60000000e+01, 5.00000000e+00,
#         1.70000000e+01, 7.30000000e+01, 7.00000000e+00, 1.90000000e+01,
#         7.70000000e+01, 7.00000000e+00, 1.80000000e+01, 7.20000000e+01,
#         8.05894800e+06, 8.92313900e+06, 1.01893470e+07, 1.24243280e+07],
#        [9.48000000e+00, 2.37600000e+01, 1.12782609e+02, 8.58333333e+00,
#         2.28750000e+01, 1.13130435e+02, 1.00000000e+01, 2.32400000e+01,
#         1.14260870e+02, 6.00000000e+00, 1.30000000e+01, 7.20000000e+01,
#         1.23475100e+06, 1.38372100e+06, 1.58212800e+06, 1.80712000e+06],
#        [9.48000000e+00, 2.37600000e+01, 1.12782609e+02, 8.58333333e+00,
#         2.28750000e+01, 1.13130435e+02, 1.00000000e+01, 2.32400000e+01,
#         1.14260870e+02, 6.00000000e+00, 3.60000000e+01, 1.66000000e+02,
#         1.95955300e+06, 2.35698600e+06, 2.67320900e+06, 3.11288000e+06],
#        [2.00000000e+00, 1.50000000e+01, 8.10000000e+01, 2.00000000e+00,
# ...

# %% [markdown]
# # Showing Data After Impution

# %%
df_trans = pd.read_csv("E:\M.Sc(DS & SA)\Sem-2\Data Driven Governance\Final Project Data\Final Datasets\ImputedSet.csv")
df_trans
# Out:
#     SO2 - 2011  NO2 - 2011  PM - 2011  SO2 - 2012  NO2 - 2012  PM - 2012  \
# 0            7          20         86           5          17         73
# 1            9          24        113           9          23        113
# 2            9          24        113           9          23        113
# 3            2          15         81           2          16         92
# 4           16          31        164          11          22        107
# 5            9          24        113           9          23        113
# 6            9          24        113           9          23        113
# 7            6          50        252           5          55        261
# 8            3          14         74          14          18         68
# 9           16          24         92          15          23         89
# 10          13          20        168          14          23        171
# 11           3          13         89           3          15         88
# ...

# %%
df_trans['State'] = df['State']
df_trans
plt.figure(figsize=(25, 18))
#ax = df_trans.plot(x="State", y="VR_2010", kind="bar")
# plotting age on the same axis
#df_trans.plot(x="State", y=["NO2 - 2009","SO2 - 2009"], kind="bar",figsize=(20, 13))
ax = df_trans.plot(x="State", y="NO2 - 2011", kind="bar")
# plotting age on the same axis
df_trans.plot(x="State", y="SO2 - 2011", kind="bar", ax=ax, color="C2",figsize=(15,13))
#df_trans.plot(x="State", y="PM - 2009", kind="bar", ax=ax, color="C3",figsize=(15,13))
# Out:
# <AxesSubplot:xlabel='State'>

# %% [markdown]
# # Data Set Save After Imputation

# %%
df_trans.to_csv(r'.\ImputedSet.csv', index = False)

# %% [markdown]
# # Correlation Matrix

# %%
df_corelation = df_trans.corr()
df_corelation
# Out:
#             SO2 - 2011  NO2 - 2011  PM - 2011  SO2 - 2012  NO2 - 2012  \
# SO2 - 2011    1.000000    0.587703   0.422123    0.742616    0.486660
# NO2 - 2011    0.587703    1.000000   0.575197    0.534806    0.967682
# PM - 2011     0.422123    0.575197   1.000000    0.378581    0.577087
# SO2 - 2012    0.742616    0.534806   0.378581    1.000000    0.513329
# NO2 - 2012    0.486660    0.967682   0.577087    0.513329    1.000000
# PM - 2012     0.432784    0.546154   0.948973    0.334074    0.578910
# SO2 - 2013    0.874129    0.574571   0.306175    0.791858    0.522419
# NO2 - 2013    0.525707    0.958205   0.602895    0.554543    0.985612
# PM - 2013     0.487631    0.565115   0.935214    0.410703    0.565055
# SO2 - 2014    0.733725    0.741490   0.213945    0.609783    0.699977
# NO2 - 2014    0.524338    0.922540   0.619529    0.523008    0.950001
# PM - 2014     0.412629    0.548960   0.905979    0.331683    0.558161
# ...

# %%
df_corelation = df_trans.corr()
print("\033[1mCorrelation Matrix:\033[1m")
print(df_corelation)
print("\033[1mFirst 5 Rows:\033[1m")
df_trans.head()
# Out:
# Correlation Matrix:
#             SO2 - 2011  NO2 - 2011  PM - 2011  SO2 - 2012  NO2 - 2012  \
# SO2 - 2011    1.000000    0.587703   0.422123    0.742616    0.486660
# NO2 - 2011    0.587703    1.000000   0.575197    0.534806    0.967682
# PM - 2011     0.422123    0.575197   1.000000    0.378581    0.577087
# SO2 - 2012    0.742616    0.534806   0.378581    1.000000    0.513329
# NO2 - 2012    0.486660    0.967682   0.577087    0.513329    1.000000
# PM - 2012     0.432784    0.546154   0.948973    0.334074    0.578910
# SO2 - 2013    0.874129    0.574571   0.306175    0.791858    0.522419
# NO2 - 2013    0.525707    0.958205   0.602895    0.554543    0.985612
# PM - 2013     0.487631    0.565115   0.935214    0.410703    0.565055
# SO2 - 2014    0.733725    0.741490   0.213945    0.609783    0.699977
# NO2 - 2014    0.524338    0.922540   0.619529    0.523008    0.950001
# PM - 2014     0.412629    0.548960   0.905979    0.331683    0.558161
# ...

# %% [markdown]
# # Data Farme Describe

# %%
df_trans.describe()
# Out:
#        SO2 - 2011  NO2 - 2011   PM - 2011  SO2 - 2012  NO2 - 2012   PM - 2012  \
# count   33.000000   33.000000   33.000000   33.000000   33.000000   33.000000
# mean     8.727273   22.181818  112.848485    8.060606   21.363636  113.090909
# std      6.170863   12.775598   45.523429    5.043185   12.822876   48.815574
# min      2.000000    6.000000   40.000000    2.000000    6.000000   38.000000
# 25%      3.000000   14.000000   86.000000    4.000000   14.000000   86.000000
# 50%      9.000000   20.000000  113.000000    9.000000   22.000000  113.000000
# 75%     11.000000   27.000000  129.000000   11.000000   23.000000  113.000000
# max     28.000000   65.000000  252.000000   23.000000   65.000000  261.000000
#
#        SO2 - 2013  NO2 - 2013   PM - 2013  SO2 - 2014  NO2 - 2014   PM - 2014  \
# count   33.000000   33.000000   33.000000   33.000000   33.000000   33.000000
# mean     9.272727   21.545455  114.181818    9.454545   21.939394  115.121212
# ...

# %% [markdown]
# # Data Frame individual Attribute Corelation

# %%
print(df_corelation['VR_2011'].sort_values(ascending=False))
# Out:
# VR_2011       1.000000
# VR_2012       0.630014
# VR_2013       0.629374
# VR_2014       0.620669
# SO2 - 2012    0.361790
# SO2 - 2013    0.300149
# SO2 - 2011    0.220502
# NO2 - 2013    0.203621
# SO2 - 2014    0.192751
# NO2 - 2014    0.192114
# NO2 - 2012    0.167870
# NO2 - 2011    0.158303
# PM - 2013    -0.012218
# PM - 2014    -0.032386
# PM - 2012    -0.032397
# PM - 2011    -0.034629
# Name: VR_2011, dtype: float64

# %% [markdown]
# # Data Plot Using seaborn

# %%
sns.pairplot(df_trans)

# %% [markdown]
# # Corelation plot

# %%
df1=pd.DataFrame()
df1['SO2 - 2011']=df['SO2 - 2011'].copy()
df1['NO2 - 2011']=df['NO2 - 2011'].copy()
df1['PM - 2011']=df['PM - 2011'].copy()

# %%
sns.pairplot(data=df1)

# %%
df2=pd.DataFrame()
df2['SO2 - 2012']=df['SO2 - 2012'].copy()
df2['NO2 - 2012']=df['NO2 - 2012'].copy()
df2['PM - 2012']=df['PM - 2012'].copy()

# %%
sns.pairplot(data=df2)

# %%
df3=pd.DataFrame()
df3['SO2 - 2013']=df['SO2 - 2013'].copy()
df3['NO2 - 2013']=df['NO2 - 2013'].copy()
df3['PM - 2013']=df['PM - 2013'].copy()

# %%
sns.pairplot(data=df3)

# %%
df4=pd.DataFrame()
df4['SO2 - 2014']=df['SO2 - 2014'].copy()
df4['NO2 - 2014']=df['NO2 - 2014'].copy()
df4['PM - 2014']=df['PM - 2014'].copy()

# %%
sns.pairplot(data=df4)

# %% [markdown]
# # Box plot

# %%
ax = sns.boxplot(df["SO2 - 2011"],linewidth=2.5,color='purple')
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df_2011 = pd.DataFrame()
df_2011['State'] = df_trans['State']
df_2011['SO2'] = df_trans['SO2 - 2011']
df_2011['NO2'] = df_trans['NO2 - 2011']
df_2011['PM'] = df_trans['PM - 2011']
df_2011['VR'] = df_trans['VR_2011']
df_2011['Year'] = 2011
df_2011
# Out:
#                           State  SO2  NO2   PM         VR  Year
# 0                Andhra Pradesh    7   20   86    8058948  2011
# 1                         Assam    9   24  113    1234751  2011
# 2                         Bihar    9   24  113    1959553  2011
# 3                    Chandigarh    2   15   81     511568  2011
# 4                  Chhattisgarh   16   31  164    2114589  2011
# 5          Dadra & Nagar Haveli    9   24  113      35059  2011
# 6                   Daman & Diu    9   24  113      42861  2011
# 7                         Delhi    6   50  252    3846721  2011
# 8                           Goa    3   14   74     673909  2011
# 9                       Gujarat   16   24   92   10998651  2011
# 10                      Haryana   13   20  168    4425221  2011
# 11             Himachal Pradesh    3   13   89     494398  2011
# 12                    Jharkhand   23   42  186    2038020  2011
# 13                    Karnataka   10   27   85    6952551  2011
# ...

# %%
df_2012 = pd.DataFrame()
df_2012['State'] = df_trans['State']
df_2012['SO2'] = df_trans['SO2 - 2012']
df_2012['NO2'] = df_trans['NO2 - 2012']
df_2012['PM'] = df_trans['PM - 2012']
df_2012['VR'] = df_trans['VR_2012']
df_2012['Year'] = 2012
df_2012
# Out:
#                           State  SO2  NO2   PM        VR  Year
# 0                Andhra Pradesh    5   17   73   8923139  2012
# 1                         Assam    9   23  113   1383721  2012
# 2                         Bihar    9   23  113   2356986  2012
# 3                    Chandigarh    2   16   92    686316  2012
# 4                  Chhattisgarh   11   22  107   2435773  2012
# 5          Dadra & Nagar Haveli    9   23  113     38635  2012
# 6                   Daman & Diu    9   23  113     43991  2012
# 7                         Delhi    5   55  261   4107912  2012
# 8                           Goa   14   18   68    727042  2012
# 9                       Gujarat   15   23   89  11872573  2012
# 10                      Haryana   14   23  171   4791825  2012
# 11             Himachal Pradesh    3   15   88    538341  2012
# 12                    Jharkhand   23   39  193   2767408  2012
# 13                    Karnataka   10   22   70   9043976  2012
# ...

# %%
df_2013 = pd.DataFrame()
df_2013['State'] = df_trans['State']
df_2013['SO2'] = df_trans['SO2 - 2013']
df_2013['NO2'] = df_trans['NO2 - 2013']
df_2013['PM'] = df_trans['PM - 2013']
df_2013['VR'] = df_trans['VR_2013']
df_2013['Year'] = 2013
df_2013
# Out:
#                           State  SO2  NO2   PM        VR  Year
# 0                Andhra Pradesh    7   19   77  10189347  2013
# 1                         Assam   10   23  114   1582128  2013
# 2                         Bihar   10   23  114   2673209  2013
# 3                    Chandigarh    2   16  102    711007  2013
# 4                  Chhattisgarh   12   27  173   2766037  2013
# 5          Dadra & Nagar Haveli   10   23  114     43010  2013
# 6                   Daman & Diu   10   23  114     47247  2013
# 7                         Delhi    5   57  222   4395086  2013
# 8                           Goa   10   18  100    790075  2013
# 9                       Gujarat   15   25   88  12993135  2013
# 10                      Haryana   13   25  146   5377003  2013
# 11             Himachal Pradesh    3   12   88    621714  2013
# 12                    Jharkhand   23   39  197   3113182  2013
# 13                    Karnataka   11   21   71   9930483  2013
# ...

# %%
df_2014 = pd.DataFrame()
df_2014['State'] = df_trans['State']
df_2014['SO2'] = df_trans['SO2 - 2014']
df_2014['NO2'] = df_trans['NO2 - 2014']
df_2014['PM'] = df_trans['PM - 2014']
df_2014['VR'] = df_trans['VR_2014']
df_2014['Year'] = 2014
df_2014
# Out:
#                           State  SO2  NO2   PM        VR  Year
# 0                Andhra Pradesh    7   18   72  12424328  2014
# 1                         Assam    6   13   72   1807120  2014
# 2                         Bihar    6   36  166   3112880  2014
# 3                    Chandigarh    2   19  110    737263  2014
# 4                  Chhattisgarh   11   26  151   3104038  2014
# 5          Dadra & Nagar Haveli    8   20  115     48550  2014
# 6                   Daman & Diu    8   20  115     52339  2014
# 7                         Delhi    5   59  237   4661714  2014
# 8                           Goa   11   17   96    865609  2014
# 9                       Gujarat   15   26   94  14413717  2014
# 10                      Haryana    9   23  147   5978110  2014
# 11             Himachal Pradesh    2   15   99    736604  2014
# 12                    Jharkhand   23   41  173   3157986  2014
# 13                    Karnataka    9   20   83  10909601  2014
# ...

# %%
df_final = pd.DataFrame()
df_final = df_2011.append(df_2012)
df_final = df_final.append(df_2013)
df_final = df_final.append(df_2014)
df_final
# Out:
#                           State  SO2  NO2   PM       VR  Year
# 0                Andhra Pradesh    7   20   86  8058948  2011
# 1                         Assam    9   24  113  1234751  2011
# 2                         Bihar    9   24  113  1959553  2011
# 3                    Chandigarh    2   15   81   511568  2011
# 4                  Chhattisgarh   16   31  164  2114589  2011
# ..                          ...  ...  ...  ...      ...   ...
# 28                  West Bengal   41   55  115  3860741  2014
# 29              Jammu & Kashmir    6   12  115   916898  2014
# 30                  Lakshadweep    2    6  115     9897  2014
# 31                      Tripura    2    6  115   204218  2014
# 32  Andaman and Nicobar Islands    2    6  115    77063  2014
#
# [132 rows x 6 columns]

# %%
# %matplotlib inline
# plotting age on the same axis
#df_final.plot(x="State", y="SO2", kind="bar", color="C1",figsize=(30,14))
#df_final.plot(x="State", y="NO2", kind="bar", color="C2",figsize=(30,14))
#df_final.plot(x="State", y="PM", kind="bar", color="C3",figsize=(30,14))
#plt.show()

# %%
df_final.to_csv('.\Data_tableau.csv', index = False)
